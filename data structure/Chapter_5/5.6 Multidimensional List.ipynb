# %% [markdown]
# ## matrix
#
# Matrix can be looked as a two-dimensional list.

# %%
# How to construt a marix 

## Flase Example : the values in the second list are referential 
data = [[0]*3]*2
print (data)
data[0][1] = 4 
print (data)
# Out:
# [[0, 0, 0], [0, 0, 0]]
# [[0, 4, 0], [0, 4, 0]]

# %%
## True Method
data = [[0]*3 for ele in range(2)]
print (data)
data[0][1] = 4
print (data)
# Out:
# [[0, 0, 0], [0, 0, 0]]
# [[0, 4, 0], [0, 0, 0]]
