# %%
import sys 
data = []
for k in range(5):
    print (data)
    a = len(data)
    b = sys.getsizeof(data)
    print ("Length: {0:3d}; Size in bytes: {1:4d}".format(a,b))
    data.append(None)
# Out:
# []
# Length:   0; Size in bytes:   56
# [None]
# Length:   1; Size in bytes:   88
# [None, None]
# Length:   2; Size in bytes:   88
# [None, None, None]
# Length:   3; Size in bytes:   88
# [None, None, None, None]
# Length:   4; Size in bytes:   88

# %% [markdown]
# 1. An empty list instance already requires a certain number of bytes of memory
