# %% [markdown]
# # Source :
#
# [Geeksforgeeks Lecture](https://www.geeksforgeeks.org/two-pointers-technique/)
#
# []

# %% [markdown]
# ## Exapmle 1 : Find two sums
#
# Two pointers is really an easy and effective technique which is typically used for searching pairs in a sorted array.
# Given a sorted array `A` (sorted in ascending order), having `N` integers, find if there exists any pair of elements `(A[i], A[j])` such that their sum is equal to `X`.

# %%
## Brute force ---> complex O(N^2)
def two_sums(A,N,X):
    for i in range(N):
        for j in range(N):
            if A[i] + A[j] == X:
                return (A[i],A[j])
    return -1

# %%
def two_points(A,N,X):
    i,j = 0, N-1 
    while i < j: 
        if A[i] + A[j] == X:
            return (A[i],A[j])
        elif A[i] + A[j] > X: ### the big number is too big, we put down
            j -= 1
        else:
            i += 1 
    return -1

# %% [markdown]
# ## Example 2: Middle of the Linked List (#876)
#
# Given a non-empty, singly linked list with head node head, return a middle node of linked list.
#
# If there are two middle nodes, return the second middle node.

# %%
nums = [-1,0,1,2,-1,-4]
nums.sort()
for i,v in enumerate(nums[:-2]):
    print (i,v)
# Out:
# 0 -4
# 1 -1
# 2 -1
# 3 0

# %%
index_map={}
for i in range(len(nums)):
    index_map[nums[i]]=i

# %%
index_map[-4]
# Out:
# 0
